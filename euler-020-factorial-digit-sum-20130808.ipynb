# %% [markdown]
# n! means n × (n − 1) × ... × 3 × 2 × 1
#
# For example, 10! = 10 × 9 × ... × 3 × 2 × 1 = 3628800,
# and the sum of the digits in the number 10! is 3 + 6 + 2 + 8 + 8 + 0 + 0 = 27.
#
# Find the sum of the digits in the number 100!

# %%
import operator

# %%
def foo(n):
    return reduce((lambda x, y: int(x) + int(y)), str(reduce(operator.mul, range(1, 100 + 1))))

# %%
n = 100
# %timeit foo(n)
foo(n)
# Out:
# 1000 loops, best of 3: 240 us per loop
# 648

# %%
def foo(n):
    return sum(map(int, str(reduce(operator.mul, range(1, 100 + 1)))))

# %%
n = 100
# %timeit foo(n)
foo(n)
# Out:
# 10000 loops, best of 3: 160 us per loop
# 648
