# %%
n = '...'

# %%
len(n)
# Out:
# 1000

# %%
from operator import mul

def foo(n, m):
    for i in xrange(len(n) - m + 1):
        # print i, n[i: i + m], 
        yield reduce(mul, map(int, n[i: i + 5]))

# %%
# %timeit max(foo(n, 5))
max(foo(n, 5))
# Out:
# 100 loops, best of 3: 6.04 ms per loop
# 40824
